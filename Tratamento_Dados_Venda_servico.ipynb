# %%
import pandas as pd
import numpy as np

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a141c8e6-b1c3-47d3-b568-ff373f930f1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a141c8e6-b1c3-47d3-b568-ff373f930f1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving relatorio_servico_analitico.xlsx to relatorio_servico_analitico.xlsx

# %%
xls = pd.ExcelFile('relatorio_servico_analitico.xlsx')
df = xls.parse('relatorio_servico_analitico', skiprows=5, index_col=None)

df.insert(0,'ID','')
df["Data"] = df["Data"].dt.strftime("%Y-%m-%d")

df['Data Última Ativação'] = pd.to_datetime(df['Data Última Ativação'],errors = 'coerce',format = '%Y-%m-%d').dt.strftime("%Y-%m-%d")

df["Valor Plano"] = df["Valor Plano"].map('{:,.2f}'.format)
df["Receita"] = df["Receita"].map('{:,.2f}'.format)

df.drop('Motivo Troca Zerada', inplace=True, axis=1)


listaVIVOEMCASA = ['RAYANE CRISTINA SANTOS', 'JOYCE CRISTINA SERAFIM', 'CARLOS EDUARDO SOUZA MOTTA DIAS', 'JARLENE APARECIDA GODOI','MYLENA MARIA FERNANDES']
def funcaoVIVOEMCASA(df):
  for i in listaVIVOEMCASA:
    for (j, row) in df.iterrows():
      vendedor = row['Vendedor']
      
      if vendedor == i:
        df['Filial'][j] =  'VIVOEMCASA'

funcaoVIVOEMCASA(df)

for (j, row) in df.iterrows():
      valorRecarga = row['Valor da Recarga']
      descontoRecarga = row['Desconto da Recarga']

      if valorRecarga == '-':
        df['Valor da Recarga'][j] =  ''

      if descontoRecarga == '-':
        df['Desconto da Recarga'][j] =  ''

for (j, row) in df.iterrows():
      filial = row['Filial']
      vendedor = row['Vendedor']

      if vendedor == "ALINE MORAES DE SOUZA MAIA" and filial == "ENTRE RIOS":
        df['Vendedor'][j] =  '1'
        df['Filial'][j] =  '14'

      if vendedor == "ANA CAROLINA CAMILO DE SOUZA LIMA E SILVA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '2'
        df['Filial'][j] =  '4'

      if vendedor == "ANA PAULA FERREIRA BORGES" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '3'
        df['Filial'][j] =  '13'
        
      if vendedor == "ANNE KATHERINE PINHEIRO RESENDE" and filial == "ENTRE RIOS":
        df['Vendedor'][j] =  '4'
        df['Filial'][j] =  '14'

      if vendedor == "ARIANE CAROLINE SILVA CARNEIRO RODRIGUES" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '5'
        df['Filial'][j] =  '8'

      if vendedor == "BARBARA LORRAINE ALVES SANTOS" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '6'
        df['Filial'][j] =  '8'

      if vendedor == "BRUNA LUIZA PEREIRA ALVES" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '7'
        df['Filial'][j] =  '1'

      if vendedor == "CAMILA CRISTINA MOREIRA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '8'
        df['Filial'][j] =  '4'

      if vendedor == "CHRISTIAN DANIEL ROGER MAXIMIANO" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '9'
        df['Filial'][j] =  '6'

      if vendedor == "CINTIA HARAMITA RAMOS DA ROCHA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '10'
        df['Filial'][j] =  '4'

      if vendedor == "CLEVERTON SOUSA ROCHA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '11'
        df['Filial'][j] =  '12'

      if vendedor == "CRISTINA MIDORI DIAS KOGA" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '12'
        df['Filial'][j] =  '6'

      if vendedor == "DEISIELLE SIMONE BRAZ VIANA FERREIRA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '13'
        df['Filial'][j] =  '3'

      if vendedor == "ELAINE APARECIDA DE OLIVEIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '14'
        df['Filial'][j] =  '1'

      if vendedor == "ELAINO GABRIEL FERREIRA SOUZA" and filial == "ESMERALDAS":
        df['Vendedor'][j] =  '15'
        df['Filial'][j] =  '16'

      if vendedor == "ELLEN FAULA CÂNDIDO" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '16'
        df['Filial'][j] =  '1'

      if vendedor == "FABIO JUNIOR SILVA" and filial == "ESMERALDAS":
        df['Vendedor'][j] =  '17'
        df['Filial'][j] =  '16'

      if vendedor == "FERNANDA CRISTINA RODRIGUES" and filial == "SABARÁ":
        df['Vendedor'][j] =  '18'
        df['Filial'][j] =  '2'

      if vendedor == "FRANCIELLE ALVES NEVES RODRIGUES" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '19'
        df['Filial'][j] =  '12'

      if vendedor == "GABRIEL RODRIGUES DE CARVALHO" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '20'
        df['Filial'][j] =  '6'

      if vendedor == "GABRIELA VIANA MARQUES" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '21'
        df['Filial'][j] =  '7'

      if vendedor == "GISELE DE SOUZA MADUREIRA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '22'
        df['Filial'][j] =  '3'

      if vendedor == "GREGORY ALEXANDER MONTEIRO NERI" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '23'
        df['Filial'][j] =  '12'

      if vendedor == "HEVERTON HENRIQUE DE OLIVEIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '24'
        df['Filial'][j] =  '1'

      if vendedor == "INGRID APARECIDA CONSTANTINO" and filial == "MARIANA":
        df['Vendedor'][j] =  '25'
        df['Filial'][j] =  '5'

      if vendedor == "IZABELA STEFANY SANTOS" and filial == "CAETÉ":
        df['Vendedor'][j] =  '26'
        df['Filial'][j] =  '10'

      if vendedor == "JESSICA LORRAINE SIQUEIRA DE AZEVEDO" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '27'
        df['Filial'][j] =  '12'

      if vendedor == "JESSICA TAMIRES RAMOS DOMINGOS" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '28'
        df['Filial'][j] =  '9'

      if vendedor == "JHEYSIANE BERNARDINO DE AZEVEDO" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '29'
        df['Filial'][j] =  '13'

      if vendedor == "JONATHAN JESUS DE PAULA" and filial == "SABARÁ":
        df['Vendedor'][j] =  '30'
        df['Filial'][j] =  '2'

      if vendedor == "JONATHAS BOSCO PEREIRA SILVA AGUIDA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '31'
        df['Filial'][j] =  '4'

      if vendedor == "KAREN CRISTINA DA SILVA VALÉRIO" and filial == "SABARÁ":
        df['Vendedor'][j] =  '32'
        df['Filial'][j] =  '2'

      if vendedor == "KARINE DOS SANTOS SILVA" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '33'
        df['Filial'][j] =  '8'

      if vendedor == "KARINE GONÇALVES DE GOES" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '34'
        df['Filial'][j] =  '11'

      if vendedor == "KAROLINE SILVÉRIO AUGUSTO" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '35'
        df['Filial'][j] =  '4'

      if vendedor == "KEROLAYNE JULIA GONZAGA" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '36'
        df['Filial'][j] =  '7'

      if vendedor == "LARYSSA MARA AGUIAR DA SILVA" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '37'
        df['Filial'][j] =  '7'

      if vendedor == "LEANDRO VIEIRA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '38'
        df['Filial'][j] =  '4'

      if vendedor == "LETICIA DE PINHO MIRANDA" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '39'
        df['Filial'][j] =  '13'

      if vendedor == "LORENA BEATRIZ NUNES DA SILVA ROSA" and filial == "CAETÉ":
        df['Vendedor'][j] =  '40'
        df['Filial'][j] =  '10'

      if vendedor == "LUANA AMANDA DE OLIVEIRA" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '41'
        df['Filial'][j] =  '8'

      if vendedor == "LUCAS CORDEIRO DE ALMEIDA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '42'
        df['Filial'][j] =  '1'

      if vendedor == "LUCIANA CHAVES DA SILVA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '43'
        df['Filial'][j] =  '12'

      if vendedor == "LUCIANA VENTURA DA SILVA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '44'
        df['Filial'][j] =  '3'

      if vendedor == "MARINA GABRIEL CARVALHO" and filial == "MARIANA":
        df['Vendedor'][j] =  '45'
        df['Filial'][j] =  '5'

      if vendedor == "NAIARA TOLEDO TOMAZ" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '46'
        df['Filial'][j] =  '7'

      if vendedor == "NAYARA GOMES DE SOUZA MOREIRA" and filial == "SANTA LUZIA":
        df['Vendedor'][j] =  '47'
        df['Filial'][j] =  '15'

      if vendedor == "PAULA EULALIA LOPES DA SILVA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '48'
        df['Filial'][j] =  '11'

      if vendedor == "PEDRO HENRIQUE PEREIRA VIEIRA" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '49'
        df['Filial'][j] =  '9'

      if vendedor == "RAFAELA CRISTINY DA COSTA SILVA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '50'
        df['Filial'][j] =  '4'

      if vendedor == "RAFAELA FERNANDES BENEVIDES DE ALMEIDA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '51'
        df['Filial'][j] =  '1'

      if vendedor == "RAYANE CRISTINA SANTOS" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '52'
        df['Filial'][j] =  '1'

      if vendedor == "ROSELI MONTEIRO" and filial == "MARIANA":
        df['Vendedor'][j] =  '53'
        df['Filial'][j] =  '5'

      if vendedor == "SAYMON BRENNER PEREIRA DIAS" and filial == "SANTA LUZIA":
        df['Vendedor'][j] =  '54'
        df['Filial'][j] =  '15'

      if vendedor == "SHEILLA ELIAS BARBOSA OLIVEIRA" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '55'
        df['Filial'][j] =  '8'

      if vendedor == "SILVIA REGIANE DE CARVALHO" and filial == "ENTRE RIOS":
        df['Vendedor'][j] =  '56'
        df['Filial'][j] =  '14'

      if vendedor == "TAIRONE HENRIQUE ROCHA" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '57'
        df['Filial'][j] =  '9'

      if vendedor == "TAMARA DE PAULA BARBOSA LIMA" and filial == "CAETÉ":
        df['Vendedor'][j] =  '58'
        df['Filial'][j] =  '10'

      if vendedor == "THAIS VIEIRA OTONI" and filial == "MARIANA":
        df['Vendedor'][j] =  '59'
        df['Filial'][j] =  '5'

      if vendedor == "VANESSA MARCIA DAMASCENO" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '60'
        df['Filial'][j] =  '6'

      if vendedor == "WARLEY DE CARVALHO PINTO" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '61'
        df['Filial'][j] =  '7'

      if vendedor == "WENDERSON ARAUJO LIMA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '62'
        df['Filial'][j] =  '3'

      if vendedor == "WILSON GUILHERME ALEX PEREIRA" and filial == "CAETÉ":
        df['Vendedor'][j] =  '63'
        df['Filial'][j] =  '10'

      if vendedor == "ALINE DE OLIVEIRA" and filial == "SANTA LUZIA":
        df['Vendedor'][j] =  '64'
        df['Filial'][j] =  '15'

      if vendedor == "ANA CAROLINA DE SOUSA" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '65'
        df['Filial'][j] =  '7'

      if vendedor == "ELBA DE MOURA GLÓRIA" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '66'
        df['Filial'][j] =  '13'

      if vendedor == "GERUZA DE CÁSSIA GONÇALVES OLIVEIRA" and filial == "CAETÉ":
        df['Vendedor'][j] =  '67'
        df['Filial'][j] =  '10'

      if vendedor == "GLAUCIANE MARIA SILVA MUNIZ" and filial == "ESMERALDAS":
        df['Vendedor'][j] =  '68'
        df['Filial'][j] =  '16'

      if vendedor == "HENRIQUE EDUARDO CURVELANO MARTINS" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '69'
        df['Filial'][j] =  '12'

      if vendedor == "JAINE BRAGA DIAS" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '70'
        df['Filial'][j] =  '11'

      if vendedor == "KEITIELY APARECIDA DA COSTA CALDEIRA" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '71'
        df['Filial'][j] =  '9'

      if vendedor == "RAFAELA DE CASSIA FERREIRA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '72'
        df['Filial'][j] =  '3'

      if vendedor == "RENAN WESLEY DE OLIVEIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '73'
        df['Filial'][j] =  '1'

      if vendedor == "RODRIGO COSTA DE OLIVEIRA" and filial == "SABARÁ":
        df['Vendedor'][j] =  '74'
        df['Filial'][j] =  '2'


      if vendedor == "CAIO CESAR CABRAL UMBELINO" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '81'
        df['Filial'][j] =  '6'

      if vendedor == "MARIANI CRISTINA VAZ DO CARMO" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '82'
        df['Filial'][j] =  '4'

      if vendedor == "OPEN BARÃO" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '83'
        df['Filial'][j] =  '9'

      if vendedor == "ANA LUIZA BRUM ANDRADE FERREIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '84'
        df['Filial'][j] =  '1'

      if vendedor == "MATHEUS VITOR MAXIMIANO GOMES" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '85'
        df['Filial'][j] =  '12'

      if vendedor == "CAREN DE CARVALHO FERREIRA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '86'
        df['Filial'][j] =  '11'

      if vendedor == "PAULA ALVES" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '87'
        df['Filial'][j] =  '4'

      if vendedor == "TAINA THAIS DE ASSIS CUSTODIO" and filial == "MARIANA":
        df['Vendedor'][j] =  '88'
        df['Filial'][j] =  '5'

      if vendedor == "PEDRO GREGÓRIO DE OLIVEIRA MAFALDA" and filial == "MARIANA":
        df['Vendedor'][j] =  '89'
        df['Filial'][j] =  '5'

      if vendedor == "ANA LUIZA BRUM - ITABIRA II" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '90'
        df['Filial'][j] =  '3'

      if vendedor == "LAURA NUNES E SOUZA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '91'
        df['Filial'][j] =  '11'

      if vendedor == "DOUGLAS OLIVEIRA BORGES RIBEIRO" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '92'
        df['Filial'][j] =  '1'

      if vendedor == "CLAUDIANE APARECIDA CAMILO" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '93'
        df['Filial'][j] =  '9'

      if vendedor == "MARIA ADRIANA MARCEILINO FERNANDES" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '95'
        df['Filial'][j] =  '1'

      if vendedor == "MARCUS VINÍCIUS DA SILVA LEITE" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '96'
        df['Filial'][j] =  '3'

      if vendedor == "TAMIRES ALVES SOUZA" and filial == "MARIANA":
        df['Vendedor'][j] =  '97'
        df['Filial'][j] =  '5'

      if vendedor == "NATANAEL ALVES RIBEIRO" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '98'
        df['Filial'][j] =  '34'

      if vendedor == "LARISSA ESTEFANE CIPRIANO" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '99'
        df['Filial'][j] =  '34'

      if vendedor == "VANESSA MARTINS DOS SANTOS" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '100'
        df['Filial'][j] =  '1'

      if vendedor == "AMANDA C NUNES DE SOUZA" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '101'
        df['Filial'][j] =  '34'

      if vendedor == "JHONES MARQUES SILVA CALAZANS" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '102'
        df['Filial'][j] =  '34'

      if vendedor == "DANIEL DUTRA ELEUTÉRIO" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '103'
        df['Filial'][j] =  '34'

      if vendedor == "RAYANE CRISTINA SANTOS" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '104'
        df['Filial'][j] =  '34'

      if vendedor == "LUAN HENRIQUE OLIVEIRA DE JESUS" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '105'
        df['Filial'][j] =  '3'

      if vendedor == "STÉPHANIE GONÇALVES DE SOUZA" and filial == "SABARÁ":
        df['Vendedor'][j] =  '106'
        df['Filial'][j] =  '2'

      if vendedor == "KENIA FLAVIA OLIVEIRA MODESTO" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '107'
        df['Filial'][j] =  '8'

      if vendedor == "OPEN" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '108'
        df['Filial'][j] =  '12'

      if vendedor == "MARIA ADRIANA MARCEILINO FERNANDES - ITABIRA II" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '109'
        df['Filial'][j] =  '3'

      if vendedor == "ISABELA SILVA DUARTE" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '110'
        df['Filial'][j] =  '34'

      if vendedor == "CAMILA VALENTE TEIXEIRA OLIVEIRA" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '111'
        df['Filial'][j] =  '34'

      if vendedor == "VICTOR CELSO SILVA MOREIRA" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '112'
        df['Filial'][j] =  '34'

      if vendedor == "ELAINE RODRIGUES DE SALES" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '113'
        df['Filial'][j] =  '34'

      if vendedor == "CAREN DE CARVALHO FERREIRA-JUSTINÓPOLIS" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '114'
        df['Filial'][j] =  '12'

      if vendedor == "PEDRO GREGÓRIO DE OLIVEIRA MAFALDA-ITABIRITO" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '115'
        df['Filial'][j] =  '7'

      if vendedor == "CINTIA HARAMITA RAMOS DA ROCHA-ITABIRITO" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '116'
        df['Filial'][j] =  '7'

      if vendedor == "FRANCIELLE ALVES NEVES RODRIGUES-Neves" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '118'
        df['Filial'][j] =  '11'

      if vendedor == "PHILIPPE GONÇALVES MIRANDA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '119'
        df['Filial'][j] =  '12'

      if vendedor == "DILLIANE KELLY INÁCIO" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '120'
        df['Filial'][j] =  '4'

      if vendedor == "GILMARA AUGUSTA JORGE ABREU" and filial == "BARAO DE COCAIS":
        df['Vendedor'][j] =  '121'
        df['Filial'][j] =  '9'

      if vendedor == "OPEN JUSTINÓPOLIS" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '122'
        df['Filial'][j] =  '12'

      if vendedor == "ISABELA SILVA DUARTE" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '123'
        df['Filial'][j] =  '1'

      if vendedor == "RENAN WESLEY DE OLIVEIRA" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '124'
        df['Filial'][j] =  '3'

      if vendedor == "LEONARDO LOPES" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '125'
        df['Filial'][j] =  '12'

      if vendedor == "VINÍCIUS SANTOS DAMASCENO" and filial == "SABARÁ":
        df['Vendedor'][j] =  '126'
        df['Filial'][j] =  '2'

      if vendedor == "MICHEL FILIPE DA COSTA REIS" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '127'
        df['Filial'][j] =  '7'

      if vendedor == "JOYCE CRISTINA SERAFIM" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '128'
        df['Filial'][j] =  '34'

      if vendedor == "JULIANA CAMPOS DE JESUS" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '129'
        df['Filial'][j] =  '4'

      if vendedor == "MICHELI CRISTINA DE SOUZA" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '130'
        df['Filial'][j] =  '4'

      if vendedor == "GABRIELA FERNANDA MARIA MARTINS" and filial == "MARIANA":
        df['Vendedor'][j] =  '131'
        df['Filial'][j] =  '5'

      if vendedor == "JÚLIA QUILER SILVEIRA" and filial == "MARIANA":
        df['Vendedor'][j] =  '132'
        df['Filial'][j] =  '5'

      if vendedor == "MICAELA APARECIDA DE OLIVEIRA MARTIR" and filial == "MARIANA":
        df['Vendedor'][j] =  '133'
        df['Filial'][j] =  '5'

      if vendedor == "LARISSA LAURENÇA INOCÊNCIO" and filial == "MARIANA":
        df['Vendedor'][j] =  '134'
        df['Filial'][j] =  '5'

      if vendedor == "OPEN MARIANA" and filial == "MARIANA":
        df['Vendedor'][j] =  '135'
        df['Filial'][j] =  '5'

      if vendedor == "KAMILLA CAMPOS VIEIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '136'
        df['Filial'][j] =  '1'

      if vendedor == "CARLA RAMOS BRAGA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '137'
        df['Filial'][j] =  '12'

      if vendedor == "OPEN OURO PRETO" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '138'
        df['Filial'][j] =  '4'

      if vendedor == "CARLOS EDUARDO SOUZA MOTTA DIAS" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '139'
        df['Filial'][j] =  '34'

      if vendedor == "OPEN VIVOEMCASA" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '140'
        df['Filial'][j] =  '34'

      if vendedor == "SABRINA SAMARA DA SILVA GOMES" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '141'
        df['Filial'][j] =  '3'

      if vendedor == "LUAN PHILIPPE ROCHA DA CRUZ" and filial == "SABARÁ":
        df['Vendedor'][j] =  '142'
        df['Filial'][j] =  '2'

      if vendedor == "ISABELA SILVA DUARTE" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '143'
        df['Filial'][j] =  '3'

      if vendedor == "CLEVERTON SOUSA ROCHA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '144'
        df['Filial'][j] =  '11'

      if vendedor == "JARLENE APARECIDA GODOI" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '145'
        df['Filial'][j] =  '34'

      if vendedor == "MATHEUS VITOR MAXIMIANO GOMES" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '146'
        df['Filial'][j] =  '11'

      if vendedor == "STÉPHANIE GONÇALVES DE SOUZA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '147'
        df['Filial'][j] =  '12'

      if vendedor == "MYLENA MARIA FERNANDES" and filial == "VIVOEMCASA":
        df['Vendedor'][j] =  '148'
        df['Filial'][j] =  '34'

      if vendedor == "NUBIA APARECIDA DE PAIVA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '149'
        df['Filial'][j] =  '11'

      if vendedor == "KETLEY FONSECA PRATES" and filial == "CONGONHAS":
        df['Vendedor'][j] =  '150'
        df['Filial'][j] =  '8'

      if vendedor == "MAX WESLLEY DOS REIS BRAGA" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '151'
        df['Filial'][j] =  '13'

      if vendedor == "OPEN ITABIRA I" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '152'
        df['Filial'][j] =  '1'

      if vendedor == "THAÍS ROSA FERREIRA PINTO CORDEIRO" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '153'
        df['Filial'][j] =  '3'

      if vendedor == "TASSYANE APARECIDA GOMES" and filial == "ITABIRA II":
        df['Vendedor'][j] =  '154'
        df['Filial'][j] =  '3'

      if vendedor == "GABRIELA FERNANDA MARIA MARTINS" and filial == "OURO PRETO":
        df['Vendedor'][j] =  '155'
        df['Filial'][j] =  '4'

      if vendedor == "NUBIA APARECIDA DE PAIVA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '156'
        df['Filial'][j] =  '12'
        
      if vendedor == "STÉPHANIE GONÇALVES DE SOUZA" and filial == "RIBEIRÃO DAS NEVES":
        df['Vendedor'][j] =  '157'
        df['Filial'][j] =  '11'

      if vendedor == "VICTOR CELSO SILVA MOREIRA" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '158'
        df['Filial'][j] =  '1'

      if vendedor == "JOYCE CRISTINA SERAFIM " and filial =="ITABIRA II":
        df['Vendedor'][j] =  '159'
        df['Filial'][j] =  '3'
      
      if vendedor == "TASSYANE APARECIDA GOMES" and filial =="BARAO DE COCAIS":
        df['Vendedor'][j] =  '160'
        df['Filial'][j] =  '9'

      if vendedor == "IGOR FERNANDES DA SILVA MARTINS" and filial =="ENTRE RIOS":
        df['Vendedor'][j] =  '161'
        df['Filial'][j] =  '14'

      if vendedor == "LUCAS PEREIRA LOPES" and filial == "SANTA LUZIA":
        df['Vendedor'][j] =  '162'
        df['Filial'][j] =  '15'
 
      if vendedor == "CLARA ELLEN RESENDE FERNANDES" and filial == "ENTRE RIOS":
        df['Vendedor'][j] =  '163'
        df['Filial'][j] =  '14'

      if vendedor == "GABRIELLA RAMOS BATISTA LOUZADO" and filial == "OURO BRANCO I":
        df['Vendedor'][j] =  '164'
        df['Filial'][j] =  '6'

      if vendedor == "CLEIDE DE JESUS JARDIM" and filial == "ITABIRITO":
        df['Vendedor'][j] =  '165'
        df['Filial'][j] =  '7'
      
      if vendedor == "MATEUS FELIPE RIBEIRO FERREIRA" and filial == "OURO BRANCO II":
        df['Vendedor'][j] =  '166'
        df['Filial'][j] =  '40'

      if vendedor == "GIOVANA FAGUNDES DE OLIVEIRA" and filial == "OURO BRANCO II":
        df['Vendedor'][j] =  '167'
        df['Filial'][j] =  '40'
      
      if vendedor == "TAYNAH MUNIZ CANGUSSU" and filial == "OURO BRANCO II":
        df['Vendedor'][j] =  '168'
        df['Filial'][j] =  '40'

      if vendedor == "WESLEY TADEU GONZAGA" and filial == "OURO BRANCO II":
        df['Vendedor'][j] =  '169'
        df['Filial'][j] =  '40'
      
      if vendedor == "VICTOR HUGO VENTEL SILVA" and filial == "OURO BRANCO II":
        df['Vendedor'][j] =  '170'
        df['Filial'][j] =  '40'

      if vendedor == "JAIDER LAGE DO CARMO" and filial == "ITABIRA I":
        df['Vendedor'][j] =  '171'
        df['Filial'][j] =  '1'

      if vendedor == "MELONY CRISTIAN MENDONÇA CARDOSO" and filial == "GUANHÃES":
        df['Vendedor'][j] =  '172'
        df['Filial'][j] =  '13'

      if vendedor == "PHILIPPE GONÇALVES MIRANDA" and filial == "SANTA LUZIA":
        df['Vendedor'][j] =  '177'
        df['Filial'][j] =  '15'

      if vendedor == "SAYMON BRENNER PEREIRA DIAS" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '178'
        df['Filial'][j] =  '12'
     
      if vendedor == "LUANA LOPES DE SOUZA" and filial == "JUSTINÓPOLIS":
        df['Vendedor'][j] =  '179'
        df['Filial'][j] =  '12'


df.to_excel(r'relatorio_servico_analitico_bi.xlsx', index = False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:386: SettingWithCopyWarning:
# ...
